# %%
import asyncio

from browser_use import Browser as BrowserUseBrowser
from browser_use import BrowserConfig
from browser_use.browser.context import BrowserContext, BrowserContextConfig

# %%
from googlesearch import search

query = "2025 f1 australia result"
loop = asyncio.get_event_loop()
links = await loop.run_in_executor(
    None, lambda: list(search(query, num_results=10))
)

# %%
links
# Out:
# ['https://www.formula1.com/en/results/2025/races/1254/australia/race-result',
#  'https://www.bbc.com/sport/live/c8j0wmpm43jt',
#  'https://www.formula1.com/en/racing/2025/australia',
#  'https://www.planetf1.com/news/f1-results-2025-australian-grand-prix',
#  'https://www.espn.com/f1/race/_/id/600052045',
#  'https://www.bbc.com/sport/formula1/2025/australian-grand-prix/results',
#  'https://www.formula1.com/en/results',
#  'https://racingnews365.com/2025-f1-australian-grand-prix-results',
#  'https://www.youtube.com/watch?v=md9-jG4RzXs',
#  'https://www.racefans.net/2025/03/16/2025-australian-grand-prix-race-result-and-championship-points/']

# %%
browser = BrowserUseBrowser(BrowserConfig(headless=False))

# %%
browser_context = await browser.new_context()

# %%
await browser_context.navigate_to(links[8])

# %%
await browser_context.go_back()

# %%
await browser_context.execute_javascript("document.body.innerText")
# Out:
# 'We value your privacy\n\nWe use cookies to enhance your browsing experience, serve personalised ads or content, and analyse our traffic. By clicking "Accept All", you consent to our use of cookies.\n\nCustomise\nReject All\nAccept All\nSkip to main content\nFORMULA 1\nBUY TICKETS\nFORMULA 1\nFormula 1 British Grand Prix\nWhat\'s On\nTickets\nOfficial Hospitality\nGetting Here\nFAQs\nACCOMMODATION\nEscapade Silverstone\nThe Ridings Glamping\nArden Paddocks Camping\nCartmel Fields Camping\nGolf Club Camping\nThe Pop Up Hotel\nImage\nEXPERIENCE BRITISH GRAND PRIX OFFICIAL HOSPITALITY >>\nMOTOGP\nBUY TICKETS\nMOTOGP™\nBritish Grand Prix MotoGP™\nWhat\'s On\nTickets\nHospitality\nFAQs\nACCOMMODATION\nEscapade Silverstone\nCartmel Fields\nImage\nBOOK YOUR PACKAGE >>\nEVENTS & TICKETS\nVIEW ALL EVENTS\nEVENTS & TICKETS\nView All Events\nOfficial Hospitality\nMOST POPULAR\nSilverstone Festival\nDAYS OUT\nSilverstone Museum\nMEMBERSHIP\nSilverstone Racing Club\nImage\nTICKETS NOW ON SALE >>\nDRIVING EXPERIENCES\nVIEW EXPERIENCES\nDRIVING EXPERIENCES\nView All Driving Experiences\nMOST POPULAR\nFormula Single Seater\nSupercar Experience\nSuperchoice Voucher\nTHE LOWDOWN\nUpcoming Drive Dates\nWays to Buy\nFAQs\nImage\nFERRARI EXPERIENCES FROM £199 >>\nTRACK DAYS\nVIEW TRACK DAYS\nTRACK DAYS & TESTING\nTrack Days & Testing Home\nCar Track Days\nTesting\nExclusive Circuit Hire\nSTAY\nEscapade Silverstone\nPROFESSIONAL TUITION\n1 to 1 Coaching\nArds Courses\nGIFT VOUCHERS\nMonetary Gift Vouchers\nImage\nBOOK A TRACK DAY >>\nBUSINESS\nGET IN TOUCH\nPLAN YOUR EVENT\nAll Events\nChristmas Parties\nCorporate Festivals\nExhibitions\nDinners\nCORPORATE HOSPITALITY\nFormula 1 Hospitality\nMotoGP Hospitality\nSilverstone Festival Hospitality\nSTAY\nEscapade Silverstone\nHilton Garden Inn Hotel\nKEEP UP TO DATE\nNews\nVISIT & STAY\nEVENT TICKETS\nVISITING\nVisit & Stay Home\nAccessibility\nGetting Here\nSilverstone Museum\nWHERE TO STAY\nEscapade Silverstone\nHilton Garden Inn Hotel\nWHERE TO EAT\nThe Gallery\nImage\nBOOK A TABLE >>\nBreadcrumb\nHome News F1 Australian Grand Prix results: Norris triumphs in wet and wild season opener\nF1 AUSTRALIAN GRAND PRIX RESULTS: NORRIS TRIUMPHS IN WET AND WILD SEASON OPENER\n17 March 2025\n\nThe 2025 Formula 1 season roared into life with a thrilling, rain-affected Australian Grand Prix at Albert Park. Pre-season speculation was finally put to rest as the true order emerged, and it was McLaren who continued their end-of-season form from 2024. Lando Norris emerged victorious after a tense battle with Max Verstappen and team-mate Oscar Piastri.\n\nHere\'s our rundown of all the key storylines from F1’s 2025 season opener in Melbourne…\n\n\xa0\n\n2025 Australian Grand Prix results\n\nPos\n\n\t\n\nDriver\n\n\t\n\nTeam\n\n\t\n\nTime/Retired\n\n\t\n\nPts\n\n\n\n\n1\n\n\t\n\nLando Norris\n\n\t\n\nMcLaren Mercedes\n\n\t\n\n1:42:06.304\n\n\t\n\n25\n\n\n\n\n2\n\n\t\n\nMax Verstappen\n\n\t\n\nRed Bull Racing Honda RBPT\n\n\t\n\n+0.895s\n\n\t\n\n18\n\n\n\n\n3\n\n\t\n\nGeorge Russell\n\n\t\n\nMercedes\n\n\t\n\n+8.481s\n\n\t\n\n15\n\n\n\n\n4\n\n\t\n\nKimi Antonelli\n\n\t\n\nMercedes\n\n\t\n\n+10.135s\n\n\t\n\n12\n\n\n\n\n5\n\n\t\n\nAlex Albon\n\n\t\n\nWilliams Mercedes\n\n\t\n\n+12.773s\n\n\t\n\n10\n\n\n\n\n6\n\n\t\n\nLance Stroll\n\n\t\n\nAston Martin Aramco Mercedes\n\n\t\n\n+17.413s\n\n\t\n\n8\n\n\n\n\n7\n\n\t\n\nNico Hulkenberg\n\n\t\n\nKick Sauber Ferrari\n\n\t\n\n+18.423s\n\n\t\n\n6\n\n\n\n\n8\n\n\t\n\nCharles Leclerc\n\n\t\n\nFerrari\n\n\t\n\n+19.826s\n\n\t\n\n4\n\n\n\n\n9\n\n\t\n\nOscar Piastri\n\n\t\n\nMcLaren Mercedes\n\n\t\n\n+20.448s\n\n\t\n\n2\n\n\n\n\n10\n\n\t\n\nLewis Hamilton\n\n\t\n\nFerrari\n\n\t\n\n+22.473s\n\n\t\n\n1\n\n\n\n\n11\n\n\t\n\nPierre Gasly\n\n\t\n\nAlpine Renault\n\n\t\n\n+26.502s\n\n\t\n\n0\n\n\n\n\n12\n\n\t\n\nYuki Tsunoda\n\n\t\n\nRacing Bulls Honda RBPT\n\n\t\n\n+29.884s\n\n\t\n\n0\n\n\n\n\n13\n\n\t\n\nEsteban Ocon\n\n\t\n\nHaas Ferrari\n\n\t\n\n+33.161s\n\n\t\n\n0\n\n\n\n\n14\n\n\t\n\nO ...

# %%
page  = await browser_context.get_current_page()
html_content = await page.content()

# %%
import markdownify
content = markdownify.markdownify(html_content)

# %%
content
# Out:
# '2025 RACE RESULTS[Skip to content](#maincontent)[![Formula 1](https://media.formula1.com/image/upload/f_auto,c_limit,w_288,q_auto/f_auto/q_auto/fom-website/etc/designs/fom-website/images/F1_75_Logo)](/)\n\n* [![Federation Internationale de l\'Automobile](https://media.formula1.com/image/upload/f_auto,c_limit,w_55,q_auto/etc/designs/fom-website/images/fia_logo)](https://www.fia.com/)\n* [F1®](/)\n* [F2™![Formula 2](https://media.formula1.com/image/upload/f_auto,c_limit,w_99,q_auto/etc/designs/fom-website/images/f2_logo)](https://www.fiaformula2.com/)\n* [F3™![Formula 3](https://media.formula1.com/image/upload/f_auto,c_limit,w_99,q_auto/etc/designs/fom-website/images/f3_logo)](https://www.fiaformula3.com/)\n* [F1® ACADEMY![F1 Academy](https://media.formula1.com/image/upload/f_auto,c_limit,w_99,q_auto/nwp-navigation/f1academy)](https://www.f1academy.com/)\n\n* [Authentics](https://www.f1authentics.com/)\n* [Store](https://f1store.formula1.com/en/?_s=bm-fi-f1-prtsite-topnav-230720-jm)\n* [Tickets](https://tickets.formula1.com)\n* [Hospitality](https://tickets.formula1.com/en/h-formula1-hospitality)\n* [Experiences](https://f1experiences.com/?utm_source=formula1.com&utm_medium=referral&utm_campaign=general)\n* [![F1® TV](https://media.formula1.com/image/upload/f_auto,c_limit,w_112,q_auto/nwp-navigation/f1-tv-logo)](https://f1tv.formula1.com)\n\n[Sign In](https://account.formula1.com/#/en/login?redirect=https%3A%2F%2Fwww.formula1.com%2Fen%2Fresults%2F2025%2Fraces&lead_source=web_f1core)[Subscribe](/subscribe-to-f1-tv)[![Formula 1](https://media.formula1.com/image/upload/f_auto,c_limit,w_285,q_auto/f_auto/q_auto/fom-website/etc/designs/fom-website/images/F1_75_Logo)](/)\n\n* [Latest](https://www.formula1.com/en/latest)\n* [Video](https://www.formula1.com/en/video)\n* [F1 Unlocked](https://www.formula1.com/en/page/discover-unlocked)\n* [Schedule](https://www.formula1.com/en/racing/2025)\n* [Results](https://www.formula1.com/en/results/2025/races)\n* [Drivers](https://www.formula1.com/en/drivers)\n* [Teams](https://www.formula1.com/en/teams)\n* [Gaming](https://www.formula1.com/en/page/gaming)\n* [Live Timing](https://www.formula1.com/en/timing/f1-live)\ndefaultmobiletabletlaptopdesktopdesktopWide20 - 23 March![F1 live race circuit](https://media.formula1.com/image/upload/f_auto,c_limit,w_112,q_auto/f_auto/q_auto/content/dam/fom-website/2018-redesign-assets/Track%20icons%204x3/China)[China![](https://media.formula1.com/content/dam/fom-website/2018-redesign-assets/year%20icon/2025.png)](https://www.formula1.com/en/racing/2025/china)\n\nSprint\n\n04\n\nhrs\n\n06\n\nmins\n\n20\n\nsecs[![TAG Heuer Clock](/assets/result/_next/static/media/face_tag.66f9a7ac.png)![](/assets/result/_next/static/media/seconds_tag.7c244cf8.png)![](/assets/result/_next/static/media/minutes_tag.5a28efc5.png)![](/assets/result/_next/static/media/hours_tag.78c17c28.png)](https://www.tagheuer.com/)\n\nSeason\n\n* [2025](/en/results/2025/races)\n* [2024](/en/results/2024/races)\n* [2023](/en/results/2023/races)\n* [2022](/en/results/2022/races)\n* [2021](/en/results/2021/races)\n* [2020](/en/results/2020/races)\n* [2019](/en/results/2019/races)\n* [2018](/en/results/2018/races)\n* [2017](/en/results/2017/races)\n* [2016](/en/results/2016/races)\n* [2015](/en/results/2015/races)\n* [2014](/en/results/2014/races)\n* [2013](/en/results/2013/races)\n* [2012](/en/results/2012/races)\n* [2011](/en/results/2011/races)\n* [2010](/en/results/2010/races)\n* [2009](/en/results/2009/races)\n* [2008](/en/results/2008/races)\n* [2007](/en/results/2007/races)\n* [2006](/en/results/2006/races)\n* [2005](/en/results/2005/races)\n* [2004](/en/results/2004/races)\n* [2003](/en/results/2003/races)\n* [2002](/en/results/2002/races)\n* [2001](/en/results/2001/races)\n* [2000](/en/results/2000/races)\n* [1999](/en/results/1999/races)\n* [1998](/en/results/1998/races)\n* [1997](/en/results/1997/races)\n* [1996](/en/results/1996/races)\n* [1995](/en/results/1995/races)\n* [1994](/en/results/ ...

# %%
session = await browser_context.get_session()
session.cached_state = await browser_context._update_state()

# %%
session.cached_state.selector_map
# Out:
# {1: <a href="#maincontent" class="p-2 bg-primary text-white shadow-inner uppercase absolute underline transition-all z-50 -top-16 left-[2px] w-max laptop:w-max focus:top-[5px] w-max"> [interactive, top, highlight:1, in-viewport],
#  3: <img> [interactive, top, highlight:3, in-viewport],
#  2: <a class="grid grid-flow-col auto-cols-max rounded-5 cursor-pointer items-center transition-colors duration-200 font-titillium font-[600] w-full min-w-max laptop:w-auto laptop:text-center laptop:auto-cols-auto focus-visible:outline focus-visible:outline-offset-2 focus-visible:outline-[3px] focus-visible:outline-carbonBlack disabled:pointer-events-none disabled:opacity-75 disabled:cursor-default  grid grid-flow-row laptop:grid-flow-col" data-path="https://www.fia.com/" data-action-type="CTA Click | " data-event="headerMastHeadClick" href="https://www.fia.com/" target="_blank"> [interactive, top, highlight:2, in-viewport],
#  4: <a class="grid grid-flow-col auto-cols-max rounded-5 cursor-pointer items-center transition-colors duration-200 font-titillium font-[600] w-full min-w-max laptop:w-auto laptop:text-center laptop:auto-cols-auto focus-visible:outline focus-visible:outline-offset-2 focus-visible:outline-[3px] focus-visible:outline-carbonBlack disabled:pointer-events-none disabled:opacity-75 disabled:cursor-default  grid grid-flow-row laptop:grid-flow-col h-[30px] laptop:h-auto text-left  laptop:px-xxs desktop:px-xs w-auto laptop:w-min" data-path="/" data-action-type="CTA Click | F1®" data-event="headerMastHeadClick" href="/" target="_self"> [interactive, top, highlight:4, in-viewport],
#  5: <a class="grid grid-flow-col auto-cols-max rounded-5 cursor-pointer items-center transition-colors duration-200 font-titillium font-[600] w-full min-w-max laptop:w-auto laptop:text-center laptop:auto-cols-auto focus-visible:outline focus-visible:outline-offset-2 focus-visible:outline-[3px] focus-visible:outline-carbonBlack disabled:pointer-events-none disabled:opacity-75 disabled:cursor-default  grid grid-flow-row laptop:grid-flow-col h-[30px] laptop:h-auto text-left  laptop:px-xxs desktop:px-xs w-auto laptop:w-min" data-path="https://www.fiaformula2.com/" data-action-type="CTA Click | Formula 2" data-event="headerMastHeadClick" href="https://www.fiaformula2.com/" target="_blank"> [interactive, top, highlight:5, in-viewport],
#  6: <a class="grid grid-flow-col auto-cols-max rounded-5 cursor-pointer items-center transition-colors duration-200 font-titillium font-[600] w-full min-w-max laptop:w-auto laptop:text-center laptop:auto-cols-auto focus-visible:outline focus-visible:outline-offset-2 focus-visible:outline-[3px] focus-visible:outline-carbonBlack disabled:pointer-events-none disabled:opacity-75 disabled:cursor-default  grid grid-flow-row laptop:grid-flow-col h-[30px] laptop:h-auto text-left  laptop:px-xxs desktop:px-xs w-auto laptop:w-min" data-path="https://www.fiaformula3.com/" data-action-type="CTA Click | Formula 3" data-event="headerMastHeadClick" href="https://www.fiaformula3.com/" target="_blank"> [interactive, top, highlight:6, in-viewport],
#  7: <a class="grid grid-flow-col auto-cols-max rounded-5 cursor-pointer items-center transition-colors duration-200 font-titillium font-[600] w-full min-w-max laptop:w-auto laptop:text-center laptop:auto-cols-auto focus-visible:outline focus-visible:outline-offset-2 focus-visible:outline-[3px] focus-visible:outline-carbonBlack disabled:pointer-events-none disabled:opacity-75 disabled:cursor-default  grid grid-flow-row laptop:grid-flow-col h-[30px] laptop:h-auto text-left  laptop:px-xxs desktop:px-xs w-auto laptop:w-min" data-path="https://www.f1academy.com/" data-action-type="CTA Click | Formula 1 Academy" data-event="headerMastHeadClick" href="https://www.f1academy.com/" target="_blank"> [interactive, top, highlight:7, in-viewport],
#  8: <a class="grid grid-flow-col auto-cols-max rounded-5 cursor-pointer items-center transition-colors duration-200 font-titillium font-[600] w-full min-w-max laptop:w-auto laptop:text-center laptop:auto-cols-auto focus-visible:outline focus-visible:outline-offset-2 focus-visible:outline-[3px] focus-visible:outline-carbonBlack disabled:pointer-events-none disabled:opacity-75 disabled:cursor-default  grid laptop:mx-1 desktop:mx-3 my-3 grid-flow-col text-14 laptop:text-12 font-formula !font-normal laptop:!font-semibold w-full laptop:w-auto grid-cols-[auto_min-content] !duration-0 text-left" data-path="https://www.f1authentics.com/" data-action-type="CTA Click | " data-event="headerMastHeadClick" href="https://www.f1authentics.com/" target="_blank"> [interactive, top, highlight:8, in-viewport],
#  9: <a class="grid grid-flow-col auto-cols-max rounded-5 cursor-pointer items-center transition-colors duration-200 font-titillium font-[600] w-full min-w-max laptop:w-auto laptop:text-center laptop:auto-cols-auto focus-visible:outline focus-visible:outline-offset-2 focus-visible:outline-[3px] focus-visible:outline-carbonBlack disabled:pointer-events-none disabled:opacity-75 disabled:cursor-default  grid laptop:mx-1 desktop:mx-3 my-3 grid-flow-col text-14 laptop:text-12 font-formula !font-normal laptop:!font-semibold w-full laptop:w-auto grid-cols-[auto_min-content] !duration-0 text-left" data-path="https://f1store.formula1.com/en/?_s=bm-fi-f1-prtsite-topnav-230720-jm" data-action-type="CTA Click | " data-event="headerMastHeadClick" href="https://f1store.formula1.com/en/?_s=bm-fi-f1-prtsite-topnav-230720-jm" target="_blank"> [interactive, top, highlight:9, in-viewport],
#  10: <a class="grid grid-flow-col auto-cols-max rounded-5 cursor-pointer items-center transition-colors duration-200 font-titillium font-[600] w-full min-w-max laptop:w-auto laptop:text-center laptop:auto-cols-auto focus-visible:outline focus-visible:outline-offset-2 focus-visible:outline-[3px] focus-visible:outline-carbonBlack disabled:pointer-events-none disabled:opacity-75 disabled:cursor-default  grid laptop:mx-1 desktop:mx-3 my-3 grid-flow-col text-14 laptop:text-12 font-formula !font-normal laptop:!font-semibold w-full laptop:w-auto grid-cols-[auto_min-content] !duration-0 text-left" data-path="https://tickets.formula1.com" data-action-type="CTA Click | " data-event="headerMastHeadClick" href="https://tickets.formula1.com" target="_blank"> [interactive, top, highlight:10, in-viewport],
#  11: <a class="grid grid-flow-col auto-cols-max rounded-5 cursor-pointer items-center transition-colors duration-200 font-titillium font-[600] w-full min-w-max laptop:w-auto laptop:text-center laptop:auto-cols-auto focus-visible:outline focus-visible:outline-offset-2 focus-visible:outline-[3px] focus-visible:outline-carbonBlack disabled:pointer-events-none disabled:opacity-75 disabled:cursor-default  grid laptop:mx-1 desktop:mx-3 my-3 grid-flow-col text-14 laptop:text-12 font-formula !font-normal laptop:!font-semibold w-full laptop:w-auto grid-cols-[auto_min-content] !duration-0 text-left" data-path="https://tickets.formula1.com/en/h-formula1-hospitality" data-action-type="CTA Click | " data-event="headerMastHeadClick" href="https://tickets.formula1.com/en/h-formula1-hospitality" target="_blank"> [interactive, top, highlight:11, in-viewport],
#  12: <a class="grid grid-flow-col auto-cols-max rounded-5 cursor-pointer items-center transition-colors duration-200 font-titillium font-[600] w-full min-w-max laptop:w-auto laptop:text-center laptop:auto-cols-auto focus-visible:outline focus-visible:outline-offset-2 focus-visible:outline-[3px] focus-visible:outline-carbonBlack disabled:pointer-events-none disabled:opacity-75 disabled:cursor-default  grid laptop:mx-1 desktop:mx-3 my-3 grid-flow-col text-14 laptop:text-12 font-formula !font-normal laptop:!font-semibold w-full laptop:w-auto grid-cols-[auto_min-content] !duration-0 text-left" data-path="https://f1experiences.com/?utm_source=formula1.com&utm_medium=referral&utm_campaign=general" data-action-type="CTA Click | " data-event="headerMastHeadClick" href="https://f1experiences.com/?utm_source=formula1.com&utm_medium=referral&utm_campaign=general" target="_blank"> [interactive, top, highlight:12, in-viewport],
#  14: <img> [interactive, top, highlight:14, in-viewport],
#  13: <a class="grid grid-flow-col auto-cols-max rounded-5 cursor-pointer items-center transition-colors duration-200 font-titillium font-[600] w-full min-w-max laptop:w-auto laptop:text-center laptop:auto-cols-auto focus-visible:outline focus-visible:outline-offset-2 focus-visible:outline-[3px] focus-visible:outline-carbonBlack disabled:pointer-events-none disabled:opacity-75 disabled:cursor-default  grid grid-flow-col text-14 laptop:text-12 font-formula laptop:font-semibold w-full laptop:w-auto grid-cols-[auto_min-content] duration-100 text-left laptop:h-max laptop:m-auto laptop:py-micro" data-path="https://f1tv.formula1.com" data-action-type="CTA Click | " data-event="headerMastHeadClick" href="https://f1tv.formula1.com" target="_blank"> [interactive, top, highlight:13, in-viewport],
#  15: <a class="grid grid-flow-col auto-cols-max rounded-5 cursor-pointer items-center transition-colors duration-200 font-titillium font-[600] w-full min-w-max laptop:w-auto laptop:text-center laptop:auto-cols-auto focus-visible:outline focus-visible:outline-offset-2 focus-visible:outline-[3px] focus-visible:outline-carbonBlack disabled:pointer-events-none disabled:opacity-75 disabled:cursor-default text-12 px-[15px] gap-[8px] h-[39px] bg-carbonBlack text-white uppercase items-center justify-center !font-[400] laptop:!font-[600] laptop:!grid hover:bg-lightBlack" data-path="https://account.formula1.com/#/en/login?redirect=https%3A%2F%2Fwww.formula1.com%2Fen%2Fpage%2Fdiscover-unlocked&lead_source=web_f1core" data-action-type="CTA Click | Sign In" data-event="headerProfileNavigation" data-testid="profile-button" href="https://account.formula1.com/#/en/login?redirect=https%3A%2F%2Fwww.formula1.com%2Fen%2Fpage%2Fdiscover-unlocked&lead_source=web_f1core"> [interactive, top, highlight:15, in-viewport],
#  16: <a class="grid grid-flow-col auto-cols-max rounded-5 cursor-pointer items-center transition-colors duration-200 font-titillium font-[600] w-full min-w-max laptop:w-auto laptop:text-center laptop:auto-cols-auto focus-visible:outline focus-visible:outline-offset-2 focus-visible:outline-[3px] focus-visible:outline-carbonBlack disabled:pointer-events-none disabled:opacity-75 disabled:cursor-default text-12 px-[15px] gap-[8px] h-[39px] bg-primary text-white shadow-inner items-center uppercase justify-center !font-[400] laptop:!font-[600] laptop:!grid laptop:hover:bg-white laptop:hover:text-carbonBlack laptop:focus:bg-white laptop:focus:text-carbonBlack" data-path="/subscribe-to-f1-tv" data-action-type="CTA Click | Subscribe" data-event="headerProfileNavigation" data-testid="subscribe-button" href="/subscribe-to-f1-tv"> [interactive, top, highlight:16, in-viewport],
#  18: <img> [interactive, top, highlight:18, in-viewport],
#  17: <a class="grid grid-flow-col auto-cols-max rounded-5 cursor-pointer items-center transition-colors duration-200 font-titillium font-[600] w-full min-w-max laptop:w-auto laptop:text-center laptop:auto-cols-auto focus-visible:outline focus-visible:outline-offset-2 focus-visible:outline-[3px] focus-visible:outline-carbonBlack disabled:pointer-events-none disabled:opacity-75 disabled:cursor-default  m-auto w-max focus-visible:rounded-5 focus-visible:outline-offset-[3px] focus-visible:outline-[3px] hidden laptop:block pr-[30px]" data-path="/" data-action-type="CTA Click | Formula 1" data-event="headerPrimaryNavigation" data-location-in-page="header" data-testid="header-logo" href="/" target="_self"> [interactive, top, highlight:17, in-viewport],
#  19: <a class="grid grid-flow-col auto-cols-max rounded-5 cursor-pointer items-center transition-colors duration-200 font-titillium font-[600] w-full min-w-max laptop:w-auto laptop:text-center laptop:auto-cols-auto focus-visible:outline focus-visible:outline-offset-2 focus-visible:outline-[3px] focus-visible:outline-carbonBlack disabled:pointer-events-none disabled:opacity-75 disabled:cursor-default  grid h-full grid-cols-[auto_max-content] laptop:grid-cols-[auto] text-12 desktop:text-14 !font-formula w-full text-white border-pink py-[13px] rounded-none text-left px-[6px] desktop:px-[12px] font-light laptop:border-0 border-r border-b rounded-br-xs laptop:rounded-none relative laptop:w-auto laptop:border-0 laptop:py-0 laptop:px-[4px] laptop:my-0 laptop:h-full laptop:text-center transition-all !outline-none " data-path="https://www.formula1.com/en/latest" data-action-type="CTA Click | Latest" data-event="headerPrimaryNavigation" href="https://www.formula1.com/en/latest" target="_self"> [interactive, top, highlight:19, in-viewport],
#  20: <a class="grid grid-flow-col auto-cols-max rounded-5 cursor-pointer items-center transition-colors duration-200 font-titillium font-[600] w-full min-w-max laptop:w-auto laptop:text-center laptop:auto-cols-auto focus-visible:outline focus-visible:outline-offset-2 focus-visible:outline-[3px] focus-visible:outline-carbonBlack disabled:pointer-events-none disabled:opacity-75 disabled:cursor-default  grid h-full grid-cols-[auto_max-content] laptop:grid-cols-[auto] text-12 desktop:text-14 !font-formula w-full text-white border-pink py-[13px] rounded-none text-left px-[6px] desktop:px-[12px] font-light laptop:border-0 border-r border-b rounded-br-xs laptop:rounded-none relative laptop:w-auto laptop:border-0 laptop:py-0 laptop:px-[4px] laptop:my-0 laptop:h-full laptop:text-center transition-all !outline-none " data-path="https://www.formula1.com/en/video" data-action-type="CTA Click | Video" data-event="headerPrimaryNavigation" href="https://www.formula1.com/en/video" target="_self"> [interactive, top, highlight:20, in-viewport],
#  21: <a class="grid grid-flow-col auto-cols-max rounded-5 cursor-pointer items-center transition-colors duration-200 font-titillium font-[600] w-full min-w-max laptop:w-auto laptop:text-center laptop:auto-cols-auto focus-visible:outline focus-visible:outline-offset-2 focus-visible:outline-[3px] focus-visible:outline-carbonBlack disabled:pointer-events-none disabled:opacity-75 disabled:cursor-default  grid h-full grid-cols-[auto_max-content] laptop:grid-cols-[auto] text-12 desktop:text-14 !font-formula w-full text-white border-pink py-[13px] rounded-none text-left px-[6px] desktop:px-[12px] font-light laptop:border-0 border-r border-b rounded-br-xs laptop:rounded-none relative laptop:w-auto laptop:border-0 laptop:py-0 laptop:px-[4px] laptop:my-0 laptop:h-full laptop:text-center transition-all !outline-none border-white" data-path="https://www.formula1.com/en/page/discover-unlocked" data-action-type="CTA Click | F1 Unlocked" data-event="headerPrimaryNavigation" href="https://www.formula1.com/en/page/discover-unlocked" target="_self"> [interactive, top, highlight:21, in-viewport],
#  22: <a class="grid grid-flow-col auto-cols-max rounded-5 cursor-pointer items-center transition-colors duration-200 font-titillium font-[600] w-full min-w-max laptop:w-auto laptop:text-center laptop:auto-cols-auto focus-visible:outline focus-visible:outline-offset-2 focus-visible:outline-[3px] focus-visible:outline-carbonBlack disabled:pointer-events-none disabled:opacity-75 disabled:cursor-default  grid h-full grid-cols-[auto_max-content] laptop:grid-cols-[auto] text-12 desktop:text-14 !font-formula w-full text-white border-pink py-[13px] rounded-none text-left px-[6px] desktop:px-[12px] font-light laptop:border-0 border-r border-b rounded-br-xs laptop:rounded-none relative laptop:w-auto laptop:border-0 laptop:py-0 laptop:px-[4px] laptop:my-0 laptop:h-full laptop:text-center transition-all !outline-none " data-path="https://www.formula1.com/en/racing/2025" data-action-type="CTA Click | Schedule" data-event="headerPrimaryNavigation" href="https://www.formula1.com/en/racing/2025" target="_self"> [interactive, top, highlight:22, in-viewport],
#  23: <a class="grid grid-flow-col auto-cols-max rounded-5 cursor-pointer items-center transition-colors duration-200 font-titillium font-[600] w-full min-w-max laptop:w-auto laptop:text-center laptop:auto-cols-auto focus-visible:outline focus-visible:outline-offset-2 focus-visible:outline-[3px] focus-visible:outline-carbonBlack disabled:pointer-events-none disabled:opacity-75 disabled:cursor-default  grid h-full grid-cols-[auto_max-content] laptop:grid-cols-[auto] text-12 desktop:text-14 !font-formula w-full text-white border-pink py-[13px] rounded-none text-left px-[6px] desktop:px-[12px] font-light laptop:border-0 border-r border-b rounded-br-xs laptop:rounded-none relative laptop:w-auto laptop:border-0 laptop:py-0 laptop:px-[4px] laptop:my-0 laptop:h-full laptop:text-center transition-all !outline-none " data-path="https://www.formula1.com/en/results/2025/races" data-action-type="CTA Click | Results" data-event="headerPrimaryNavigation" href="https://www.formula1.com/en/results/2025/races" target="_self"> [interactive, top, highlight:23, in-viewport],
#  24: <a class="grid grid-flow-col auto-cols-max rounded-5 cursor-pointer items-center transition-colors duration-200 font-titillium font-[600] w-full min-w-max laptop:w-auto laptop:text-center laptop:auto-cols-auto focus-visible:outline focus-visible:outline-offset-2 focus-visible:outline-[3px] focus-visible:outline-carbonBlack disabled:pointer-events-none disabled:opacity-75 disabled:cursor-default  grid h-full grid-cols-[auto_max-content] laptop:grid-cols-[auto] text-12 desktop:text-14 !font-formula w-full text-white border-pink py-[13px] rounded-none text-left px-[6px] desktop:px-[12px] font-light laptop:border-0 border-r border-b rounded-br-xs laptop:rounded-none relative laptop:w-auto laptop:border-0 laptop:py-0 laptop:px-[4px] laptop:my-0 laptop:h-full laptop:text-center transition-all !outline-none " data-path="https://www.formula1.com/en/drivers" data-action-type="CTA Click | Drivers" data-event="headerPrimaryNavigation" href="https://www.formula1.com/en/drivers" target="_self"> [interactive, top, highlight:24, in-viewport],
#  25: <a class="grid grid-flow-col auto-cols-max rounded-5 cursor-pointer items-center transition-colors duration-200 font-titillium font-[600] w-full min-w-max laptop:w-auto laptop:text-center laptop:auto-cols-auto focus-visible:outline focus-visible:outline-offset-2 focus-visible:outline-[3px] focus-visible:outline-carbonBlack disabled:pointer-events-none disabled:opacity-75 disabled:cursor-default  grid h-full grid-cols-[auto_max-content] laptop:grid-cols-[auto] text-12 desktop:text-14 !font-formula w-full text-white border-pink py-[13px] rounded-none text-left px-[6px] desktop:px-[12px] font-light laptop:border-0 border-r border-b rounded-br-xs laptop:rounded-none relative laptop:w-auto laptop:border-0 laptop:py-0 laptop:px-[4px] laptop:my-0 laptop:h-full laptop:text-center transition-all !outline-none " data-path="https://www.formula1.com/en/teams" data-action-type="CTA Click | Teams" data-event="headerPrimaryNavigation" href="https://www.formula1.com/en/teams" target="_self"> [interactive, top, highlight:25, in-viewport],
#  26: <a class="grid grid-flow-col auto-cols-max rounded-5 cursor-pointer items-center transition-colors duration-200 font-titillium font-[600] w-full min-w-max laptop:w-auto laptop:text-center laptop:auto-cols-auto focus-visible:outline focus-visible:outline-offset-2 focus-visible:outline-[3px] focus-visible:outline-carbonBlack disabled:pointer-events-none disabled:opacity-75 disabled:cursor-default  grid h-full grid-cols-[auto_max-content] laptop:grid-cols-[auto] text-12 desktop:text-14 !font-formula w-full text-white border-pink py-[13px] rounded-none text-left px-[6px] desktop:px-[12px] font-light laptop:border-0 border-r border-b rounded-br-xs laptop:rounded-none relative laptop:w-auto laptop:border-0 laptop:py-0 laptop:px-[4px] laptop:my-0 laptop:h-full laptop:text-center transition-all !outline-none " data-path="https://www.formula1.com/en/page/gaming" data-action-type="CTA Click | Gaming" data-event="headerPrimaryNavigation" href="https://www.formula1.com/en/page/gaming" target="_self"> [interactive, top, highlight:26, in-viewport],
#  27: <a class="grid grid-flow-col auto-cols-max rounded-5 cursor-pointer items-center transition-colors duration-200 font-titillium font-[600] w-full min-w-max laptop:w-auto laptop:text-center laptop:auto-cols-auto focus-visible:outline focus-visible:outline-offset-2 focus-visible:outline-[3px] focus-visible:outline-carbonBlack disabled:pointer-events-none disabled:opacity-75 disabled:cursor-default  grid h-full grid-cols-[auto_max-content] laptop:grid-cols-[auto] text-12 desktop:text-14 !font-formula w-full text-white border-pink py-[13px] rounded-none text-left px-[6px] desktop:px-[12px] font-light laptop:border-0 border-r border-b rounded-br-xs laptop:rounded-none relative laptop:w-auto laptop:border-0 laptop:py-0 laptop:px-[4px] laptop:my-0 laptop:h-full laptop:text-center transition-all !outline-none " data-path="https://www.formula1.com/en/timing/f1-live" data-action-type="CTA Click | Live Timing" data-event="headerPrimaryNavigation" href="https://www.formula1.com/en/timing/f1-live" target="_self"> [interactive, top, highlight:27, in-viewport],
#  0: <header> [interactive, top, highlight:0, in-viewport],
#  28: <img> [interactive, top, highlight:28, in-viewport],
#  30: <img> [interactive, top, highlight:30, in-viewport],
#  29: <a class="grid grid-flow-col auto-cols-max rounded-5 cursor-pointer items-center transition-colors duration-200 font-titillium font-[600] w-full min-w-max laptop:w-auto laptop:text-center laptop:auto-cols-auto focus-visible:outline focus-visible:outline-offset-2 focus-visible:outline-[3px] focus-visible:outline-carbonBlack disabled:pointer-events-none disabled:opacity-75 disabled:cursor-default  !font-formula text-16 tablet:text-25 desktop:text-32 desktop:leading-8 uppercase group !min-w-min mobile:!min-w-max !text-left focus-visible:!outline-brand-white" data-path="https://www.formula1.com/en/racing/2025/china" data-event="eventTrackerClickEvents" data-click-text="China" data-event-type="Sprint" href="https://www.formula1.com/en/racing/2025/china"> [interactive, top, highlight:29, in-viewport],
#  32: <img alt="" src="/assets/page/_next/static/media/hours_tag.78c17c28.png" class="animate-hours block w-full h-full m-0 absolute" role="presentation" style="animation-delay: -57930s;"> [interactive, top, highlight:32, in-viewport],
#  31: <a href="https://www.tagheuer.com/" target="_blank" class="promotion-clock block h-full w-full aspect-square relative overflow-hidden rounded-full" data-race-name="FORMULA 1 HEINEKEN CHINESE GRAND PRIX 2025" data-page-name="Discover F1 Unlocked"> [interactive, top, highlight:31, in-viewport],
#  33: <img> [interactive, top, highlight:33, in-viewport],
#  34: <button class="grid grid-flow-col auto-cols-max rounded-5 cursor-pointer items-center transition-colors duration-200 font-titillium font-[600] w-full min-w-max laptop:w-auto laptop:text-center laptop:auto-cols-auto focus-visible:outline focus-visible:outline-offset-2 focus-visible:outline-[3px] focus-visible:outline-carbonBlack disabled:pointer-events-none disabled:opacity-75 disabled:cursor-default text-12 px-[15px] gap-[8px] h-[39px] bg-white text-carbonBlack uppercase border-[1px] shadow-innerBlack transition-shadow duration-200 hover:shadow-inner !w-max border-primary !border-2 focus:!bg-primary focus:!text-white hover:!bg-primary hover:!text-white scrollToSkinny" data-path="#skinny-registration" data-event="clickTileEvent" data-page-name="Discover F1 Unlocked" data-location-in-page="discoveryPageComponents" data-navigation-element="Get closer to the inside world of F1®​" data-click-text="Join F1 Unlocked free" type="button" data-lead-source="web_f1core" data-path-type="onpage" data-is-freewall-visible="false"> [interactive, top, highlight:34, in-viewport],
#  35: <img> [interactive, top, highlight:35, in-viewport],
#  36: <button class="grid grid-flow-col auto-cols-max rounded-5 cursor-pointer items-center transition-colors duration-200 font-titillium font-[600] w-full min-w-max laptop:w-auto laptop:text-center laptop:auto-cols-auto focus-visible:outline focus-visible:outline-offset-2 focus-visible:outline-[3px] focus-visible:outline-carbonBlack disabled:pointer-events-none disabled:opacity-75 disabled:cursor-default text-12 px-[15px] gap-[8px] h-[39px] bg-white text-carbonBlack uppercase border-[1px] shadow-innerBlack transition-shadow duration-200 hover:shadow-inner !w-max border-primary !border-2 focus:!bg-primary focus:!text-white hover:!bg-primary hover:!text-white scrollToSkinny" data-path="#skinny-registration" data-event="clickTileEvent" data-page-name="Discover F1 Unlocked" data-location-in-page="discoveryPageComponents" data-navigation-element="Unforgettable prizes & VIP experiences" data-click-text="Join F1 Unlocked free" type="button" data-lead-source="web_f1core" data-path-type="onpage" data-is-freewall-visible="false"> [interactive, top, highlight:36, in-viewport],
#  37: <img> [interactive, top, highlight:37, in-viewport]}

# %%
await browser.close()
